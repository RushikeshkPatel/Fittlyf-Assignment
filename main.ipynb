# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("unemployment_analysis.csv")

# %%
print(df)
# Out:
#                     Country Name Country Code        1991        1992  \
# 0    Africa Eastern and Southern          AFE    7.8 lacs   7.84 lacs
# 1                    Afghanistan          AFG  10.65 lacs  10.82 lacs
# 2     Africa Western and Central          AFW   4.42 lacs   4.53 lacs
# 3                         Angola          AGO   4.21 lacs   4.21 lacs
# 4                        Albania          ALB  10.31 lacs  30.01 lacs
# ..                           ...          ...         ...         ...
# 230                        Samoa          WSM    2.1 lacs   2.38 lacs
# 231                  Yemen, Rep.          YEM   8.32 lacs   8.31 lacs
# 232                 South Africa          ZAF  29.95 lacs  29.98 lacs
# 233                       Zambia          ZMB   18.9 lacs  19.37 lacs
# 234                     Zimbabwe          ZWE   4.94 lacs   4.99 lacs
#
#            1993        1994        1995        1996        1997        1998  \
# ...

# %%
df.head(5)
# Out:
#                   Country Name Country Code        1991        1992  \
# 0  Africa Eastern and Southern          AFE    7.8 lacs   7.84 lacs
# 1                  Afghanistan          AFG  10.65 lacs  10.82 lacs
# 2   Africa Western and Central          AFW   4.42 lacs   4.53 lacs
# 3                       Angola          AGO   4.21 lacs   4.21 lacs
# 4                      Albania          ALB  10.31 lacs  30.01 lacs
#
#          1993        1994        1995        1996        1997        1998  \
# 0   7.85 lacs   7.84 lacs   7.83 lacs   7.84 lacs   7.86 lacs   7.81 lacs
# 1  10.72 lacs  10.73 lacs  11.18 lacs  10.96 lacs  10.78 lacs   10.8 lacs
# 2   4.55 lacs   4.54 lacs   4.53 lacs   4.57 lacs    4.6 lacs   4.66 lacs
# 3   4.23 lacs   4.16 lacs   4.11 lacs    4.1 lacs   4.09 lacs   4.07 lacs
# 4  25.26 lacs  20.84 lacs  14.61 lacs  13.93 lacs  16.88 lacs  20.05 lacs
#
#    ...        2012        2013        2014        2015        2016  \
# ...

# %%
df1=df[df.columns[2:33]].replace('lacs','',regex=True).astype(float)
df1
# Out:
#       1991   1992   1993   1994   1995   1996   1997   1998   1999   2000  \
# 0     7.80   7.84   7.85   7.84   7.83   7.84   7.86   7.81   7.79   7.72
# 1    10.65  10.82  10.72  10.73  11.18  10.96  10.78  10.80  10.81  10.81
# 2     4.42   4.53   4.55   4.54   4.53   4.57   4.60   4.66   4.86   4.92
# 3     4.21   4.21   4.23   4.16   4.11   4.10   4.09   4.07   4.05   4.03
# 4    10.31  30.01  25.26  20.84  14.61  13.93  16.88  20.05  20.84  19.03
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 230   2.10   2.38   2.63   3.04   3.19   3.47   3.90   4.18   4.48   4.66
# 231   8.32   8.31   8.35   8.34   8.96   9.59  10.20  10.81  11.46  11.56
# 232  29.95  29.98  29.92  29.89  29.89  29.87  29.91  29.95  29.91  29.88
# 233  18.90  19.37  19.70  18.43  16.81  15.30  13.64  12.00  12.44  12.93
# 234   4.94   4.99   4.97   4.96   5.63   6.25   6.93   6.46   6.00   5.69
#
#      ...   2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# ...

# %%
df3 = df.iloc[:, :2].join(df1)
df3
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  235 non-null    object
#  1   Country Code  235 non-null    object
#  2   1991          235 non-null    float64
#  3   1992          235 non-null    float64
#  4   1993          235 non-null    float64
#  5   1994          235 non-null    float64
#  6   1995          235 non-null    float64
#  7   1996          235 non-null    float64
#  8   1997          235 non-null    float64
#  9   1998          235 non-null    float64
#  10  1999          235 non-null    float64
#  11  2000          234 non-null    float64
#  12  2001          235 non-null    float64
#  13  2002          235 non-null    float64
#  14  2003          235 non-null    float64
#  15  2004          235 non-null    float64
#  16  2005          235 non-null    float64
# ...

# %%
df3[["Country Name", "Country Code"]]
# Out:
#                     Country Name Country Code
# 0    Africa Eastern and Southern          AFE
# 1                    Afghanistan          AFG
# 2     Africa Western and Central          AFW
# 3                         Angola          AGO
# 4                        Albania          ALB
# ..                           ...          ...
# 230                        Samoa          WSM
# 231                  Yemen, Rep.          YEM
# 232                 South Africa          ZAF
# 233                       Zambia          ZMB
# 234                     Zimbabwe          ZWE
#
# [235 rows x 2 columns]

# %%
# que. 5
df3.head()
d1 = (df3.iloc[:, 2:].sum(axis=1)).reset_index()
d2 = df3.iloc[:, 0].reset_index()

ans = d1.merge(d2)

ans.rename(columns={0:"Unemployed_People"}, inplace=True)

ans[["Country Name", "Unemployed_People"]]
# Out:
#                     Country Name  Unemployed_People
# 0    Africa Eastern and Southern             224.57
# 1                    Afghanistan             345.38
# 2     Africa Western and Central             153.27
# 3                         Angola             169.02
# 4                        Albania             505.86
# ..                           ...                ...
# 230                        Samoa             180.98
# 231                  Yemen, Rep.             365.60
# 232                 South Africa             875.21
# 233                       Zambia             407.96
# 234                     Zimbabwe             160.50
#
# [235 rows x 2 columns]

# %%
df3.interpolate(inplace=True)
df3
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
df3.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 1991            0
# 1992            0
# 1993            0
# 1994            0
# 1995            0
# 1996            0
# 1997            0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
df3[df3["Country Name"].isin(["Benin", "Bahrain"])].describe()
# Out:
#            1991      1992      1993      1994      1995      1996      1997  \
# count  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000  2.000000
# mean   1.250000  1.280000  1.210000  1.235000  1.165000  1.130000  1.095000
# std    0.339411  0.325269  0.282843  0.176777  0.120208  0.070711  0.007071
# min    1.010000  1.050000  1.010000  1.110000  1.080000  1.080000  1.090000
# 25%    1.130000  1.165000  1.110000  1.172500  1.122500  1.105000  1.092500
# 50%    1.250000  1.280000  1.210000  1.235000  1.165000  1.130000  1.095000
# 75%    1.370000  1.395000  1.310000  1.297500  1.207500  1.155000  1.097500
# max    1.490000  1.510000  1.410000  1.360000  1.250000  1.180000  1.100000
#
#            1998      1999      2000  ...      2012      2013     2014  \
# count  2.000000  2.000000  2.000000  ...  2.000000  2.000000  2.00000
# mean   1.050000  1.015000  0.965000  ...  1.835000  1.735000  1.66000
# std    0.042426  0.106066  0.162635  ...  0.898026  0.784889  0.66468
# ...

# %%
co = df3[df3["Country Name"].isin(["Benin", "Bahrain"])].iloc[:, 2:]
co.head()
# Out:
#     1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2012  \
# 14  1.49  1.51  1.41  1.36  1.25  1.18  1.10  1.02  0.94  0.85  ...  2.47
# 18  1.01  1.05  1.01  1.11  1.08  1.08  1.09  1.08  1.09  1.08  ...  1.20
#
#     2013  2014  2015  2016  2017  2018  2019  2020  2021
# 14  2.29  2.13  2.01  1.83  1.64  1.47  1.47  1.58  1.57
# 18  1.18  1.19  1.20  1.19  1.18  1.20  1.20  1.78  1.87
#
# [2 rows x 31 columns]

# %%
# que. 3
def convert_cols(df):
    for cols in df.columns:
        print(cols)

convert_cols(df3)
# Out:
# Country Name
# Country Code
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
# df3.groupby("Country Name").sum()["1991"].reset_index()
# df3.set_index(convert_cols)
d1 = df3.iloc[:, 0:1].reset_index()
d2 = df3.iloc[:, 1:2].reset_index()
d3 = df3.iloc[:, 2:].transpose().reset_index()
d4 = d1.merge(d2)
# d3.join(d4)
d4[["Country Name", "Country Code"]]
d3
# Out:
#    index     0      1     2     3      4      5     6      7      8  ...  \
# 0   1991  7.80  10.65  4.42  4.21  10.31  11.62  1.87   5.44   1.60  ...
# 1   1992  7.84  10.82  4.53  4.21  30.01  12.12  1.84   6.36   1.80  ...
# 2   1993  7.85  10.72  4.55  4.23  25.26  12.86  1.85  10.10   5.30  ...
# 3   1994  7.84  10.73  4.54  4.16  20.84  12.95  1.81  11.76   6.60  ...
# 4   1995  7.83  11.18  4.53  4.11  14.61  13.32  1.80  18.80   6.70  ...
# 5   1996  7.84  10.96  4.57  4.10  13.93  12.38  1.90  17.11   9.30  ...
# 6   1997  7.86  10.78  4.60  4.09  16.88  11.95  1.98  14.82  10.80  ...
# 7   1998  7.81  10.80  4.66  4.07  20.05  11.97  2.14  12.65   9.40  ...
# 8   1999  7.79  10.81  4.86  4.05  20.84  12.11  2.22  14.05  11.20  ...
# 9   2000  7.72  10.81  4.92  4.03  19.03  12.60  2.25  15.00  11.05  ...
# 10  2001  7.73  10.81  4.87  4.00  18.58  12.47  2.49  17.32  10.91  ...
# 11  2002  7.96  11.26  4.78  3.96  17.90  12.47  2.65  19.59  10.78  ...
# ...

# %%
df3.rename(columns={"Country Name": "Country_name", "Country Code":"Country_code"})
# Out:
#                     Country_name Country_code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
def descriptive_stats(df):
    
    country = df.groupby("Country Name")
    
    d1 = df.iloc[:, 2:].min()
    d2 = df.iloc[:, 2:].max()
    d3 = df["Country Name"]

    pd.concat([d1, d2], axis=1).rename(columns={0: "minimum_unemployment", 1:"maximum_unemployment"})
    
    print("Mean, Median, Mode and Standar Deviation of given data:\n",
         country.agg(["mean", "median", "std"]).reset_index().head(10)) # displaying top 10 countrie only
    
    print("\nMinimum and Maximum unemployment:\n", 
             pd.concat([d1, d2], axis=1).rename(columns={0: "minimum_unemployment", 1:"maximum_unemployment"}))
    
    print("\nTop 5 countries which had maximum unemployment in 2021:\n",
          df[["Country Name", "2021"]].sort_values(by="2021", ascending=False).head())
    
    print("\nTop 3 countries that have unemployement greater than 5 lacs:\n",
          df3[["Country Name", "2021"]].sort_values(by="2021", ascending=False).head(3))
    
    
descriptive_stats(df3)
# Out:
# Mean, Median, Mode and Standar Deviation of given data:
#                    Country Name   1991              1992              1993  \
#                                  mean median std   mean median std   mean
# 0                  Afghanistan  10.65  10.65 NaN  10.82  10.82 NaN  10.72
# 1  Africa Eastern and Southern   7.80   7.80 NaN   7.84   7.84 NaN   7.85
# 2   Africa Western and Central   4.42   4.42 NaN   4.53   4.53 NaN   4.55
# 3                      Albania  10.31  10.31 NaN  30.01  30.01 NaN  25.26
# 4                      Algeria  20.60  20.60 NaN  24.38  24.38 NaN  26.23
# 5                       Angola   4.21   4.21 NaN   4.21   4.21 NaN   4.23
# 6                   Arab World  11.62  11.62 NaN  12.12  12.12 NaN  12.86
# 7                    Argentina   5.44   5.44 NaN   6.36   6.36 NaN  10.10
# 8                      Armenia   1.60   1.60 NaN   1.80   1.80 NaN   5.30
# 9                    Australia   9.58   9.58 NaN  10.73  10.73 NaN  10.87
#
# ...

# %%
# top 5 countries which had maximum unemployment in 2021
df3[["Country Name", "2021"]].sort_values(by="2021", ascending=False).head()
# Out:
#            Country Name   2021
# 232        South Africa  33.56
# 49             Djibouti  28.39
# 199            Eswatini  25.76
# 172  West Bank and Gaza  24.90
# 28             Botswana  24.72

# %%
df3[["Country Name", "2021"]].sort_values(by="2021", ascending=False).head(3)
# Out:
#      Country Name   2021
# 232  South Africa  33.56
# 49       Djibouti  28.39
# 199      Eswatini  25.76

# %%
# mean = df3.iloc[:, 2:].mean()
# df3.iloc[:, 2:].median()
# df3.iloc[:, 2:].mode()
# df3.iloc[:, 2:].std()

d1 = (df3.iloc[:, 2:].sum(axis=1)).reset_index()
d2 = df3.iloc[:, 0].reset_index()

ans = d1.merge(d2)

ans.rename(columns={0:"Unemployed_People"}, inplace=True)

ans[["Country Name", "Unemployed_People"]]
ans["Unemployed_People"].median()
# Out:
# 197.94999999999996

# %%
country = df3.groupby("Country Name")

# country.agg(["mode", "mean", "median", "std"])
country.agg(["mean", "median", "std"])

# unable to find mode
# Out:
# C:\Users\Rushikesh Patel\AppData\Local\Temp\ipykernel_20148\863996165.py:4: FutureWarning: ['Country Code'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   country.agg(["mean", "median", "std"])
#                               1991              1992              1993         \
#                               mean median std   mean median std   mean median
# Country Name
# Afghanistan                  10.65  10.65 NaN  10.82  10.82 NaN  10.72  10.72
# Africa Eastern and Southern   7.80   7.80 NaN   7.84   7.84 NaN   7.85   7.85
# Africa Western and Central    4.42   4.42 NaN   4.53   4.53 NaN   4.55   4.55
# Albania                      10.31  10.31 NaN  30.01  30.01 NaN  25.26  25.26
# Algeria                      20.60  20.60 NaN  24.38  24.38 NaN  26.23  26.23
# ...                            ...    ...  ..    ...    ...  ..    ...    ...
# ...

# %%
d1 = df3.iloc[:, 2:].min()

d2 = df3.iloc[:, 2:].max()

d3 = df3["Country Name"]

(pd.concat([d1, d2], axis=1).rename(columns={0: "minimum_unemployment", 1:"maximum_unemployment"}))
# Out:
#       minimum_unemployment  maximum_unemployment
# 1991              0.300000                 36.12
# 1992              0.340000                 36.39
# 1993              0.410000                 36.74
# 1994              0.470000                 36.98
# 1995              0.500000                 37.34
# 1996              0.560000                 38.80
# 1997              0.540000                 37.94
# 1998              0.560000                 37.16
# 1999              0.570000                 36.35
# 2000              0.580000                 35.46
# 2001              0.560000                111.20
# 2002              0.550000                 33.86
# 2003              0.590000                 36.69
# 2004              0.610000                 37.16
# 2005              0.000008                 37.25
# 2006              0.000110                 36.03
# 2007              0.400000                 34.93
# 2008              0.310000                 33.76
# ...

# %%
df3.iloc[:, 1:12][df3["Country Code"] == "BGR"].describe()
# df3.iloc[:, 12:][df3["Country Code"] == "BGR"].describe()

min_parameter = df3[df3["Country Code"] == "BGR"].describe()
min_parameter.loc['min'].reset_index().min()
# Out:
# index    1991
# min      4.23
# dtype: object

# %%
temp = df3[["Country Name", "Country Code"]]
temp.join(df3.iloc[:, 2:].pct_change().round(2))
# Out:
#                     Country Name Country Code  1991  1992  1993  1994  1995  \
# 0    Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 1                    Afghanistan          AFG  0.37  0.38  0.37  0.37  0.43
# 2     Africa Western and Central          AFW -0.58 -0.58 -0.58 -0.58 -0.59
# 3                         Angola          AGO -0.05 -0.07 -0.07 -0.08 -0.09
# 4                        Albania          ALB  1.45  6.13  4.97  4.01  2.55
# ..                           ...          ...   ...   ...   ...   ...   ...
# 230                        Samoa          WSM -0.56 -0.52 -0.50 -0.45 -0.43
# 231                  Yemen, Rep.          YEM  2.96  2.49  2.17  1.74  1.81
# 232                 South Africa          ZAF  2.60  2.61  2.58  2.58  2.34
# 233                       Zambia          ZMB -0.37 -0.35 -0.34 -0.38 -0.44
# 234                     Zimbabwe          ZWE -0.74 -0.74 -0.75 -0.73 -0.67
#
# ...

# %%
df3[df3["Country Name"] == "Japan"].describe().loc['min']
# Out:
# 1991    2.10
# 1992    2.20
# 1993    2.50
# 1994    2.90
# 1995    3.20
# 1996    3.40
# 1997    3.40
# 1998    4.10
# 1999    4.70
# 2000    4.75
# 2001    5.02
# 2002    5.39
# 2003    5.25
# 2004    4.73
# 2005    4.45
# 2006    4.19
# 2007    3.89
# 2008    4.00
# 2009    5.07
# 2010    5.10
# 2011    4.55
# 2012    4.36
# 2013    4.00
# 2014    3.60
# 2015    3.40
# 2016    3.10
# 2017    2.80
# 2018    2.40
# 2019    2.40
# 2020    2.80
# 2021    2.80
# Name: min, dtype: float64

# %%
filtered_df = df3[["Country Code", "2019", "2020", "2021"]][df3["Country Code"].isin(["MDA", "NAC", "PAN", "PAK", "UGA"])]
filtered_df
# Out:
#     Country Code  2019   2020   2021
# 130          MDA  5.10   3.82   3.96
# 148          NAC  3.89   8.21   5.70
# 161          PAK  3.54   4.30   4.35
# 162          PAN  4.73  12.85  12.09
# 218          UGA  1.92   2.77   2.94

# %%
total_employees = filtered_df['2019'].sum() + filtered_df['2020'].sum() + filtered_df['2021'].sum()
total_employees
# Out:
# 80.17

# %%
filtered_df['Total Employees'] = filtered_df.iloc[:, 1:].sum(axis=1)
filtered_df
# Out:
#     Country Code  2019   2020   2021  Total Employees
# 130          MDA  5.10   3.82   3.96            12.88
# 148          NAC  3.89   8.21   5.70            17.80
# 161          PAK  3.54   4.30   4.35            12.19
# 162          PAN  4.73  12.85  12.09            29.67
# 218          UGA  1.92   2.77   2.94             7.63

# %%
filtered_df["2019"]/filtered_df["Total Employees"]
# Out:
# 130    0.395963
# 148    0.218539
# 161    0.290402
# 162    0.159420
# 218    0.251638
# dtype: float64

# %%
df = df3.iloc[:, 2:][df3["Country Code"] == "LSO"]
df
# Out:
#       1991   1992   1993   1994   1995   1996   1997   1998   1999   2000  \
# 123  36.12  36.39  36.74  36.98  37.34  37.59  37.94  37.16  36.35  35.46
#
#      ...   2012   2013   2014   2015   2016  2017   2018   2019   2020  2021
# 123  ...  25.37  24.58  24.22  23.84  23.48  23.2  22.81  22.44  24.56  24.6
#
# [1 rows x 31 columns]

# %%
df1 = df3.sort_values('2021', ascending=False)
df11 =df1.head(10)

plt.bar(df11['Country Name'], df11['2021'])
plt.xticks(rotation=90)
plt.xlabel('Country Name')
plt.ylabel('2021 (%)')
plt.title('Top 10 Countries in Unemployment - 2021')
plt.show()
